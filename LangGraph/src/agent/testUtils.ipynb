# %%
from utils import get_url

# %%
url = get_url("/Users/jajajou1778/UIT_DOCS_AGENT/data/daa/quy-dinh/quy-dinh-bo-gddt/pdf/01_2017_qd-ttg_ban_hanh_danh_muc_gddt_cua_he_thong_giao_duc_quoc_dan.pdf")
print(url)
# Out:
# https://daa.uit.edu.vn/sites/daa/files/202311/01_2017_qd-ttg_ban_hanh_danh_muc_gddt_cua_he_thong_giao_duc_quoc_dan.pdf
