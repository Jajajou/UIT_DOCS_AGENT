# %%
import os
from dotenv import load_dotenv
load_dotenv()
open_ai_api_key = os.getenv("OPENAI_API_KEY")
langsmith_api_key = os.getenv("LANGSMITH_API_KEY")
print(f"API Key: {open_ai_api_key}")
print(f"Langsmith Key: {langsmith_api_key}")
