# %%
import glob
import os
from langgraph_sdk import get_sync_client
from tqdm import tqdm
import time

# %%
root_dir = "firecrawl/data/daa"

pdf_paths = sorted(
    os.path.abspath(p) for p in glob.glob(os.path.join(root_dir, '**', '*.pdf'), recursive=True)
)

client = get_sync_client(url="http://localhost:2024")

for path in tqdm(pdf_paths, desc=f"Uploading"):
    for chunk in client.runs.stream(
        None,
        "index",
        input={
            "messages":[
                {"role": "human",
                "content": f"upload {path}"}
            ]
        },
        stream_mode="updates"
    ):
        # print(f"Receiving new event of type: {chunk.event}")
        # print(chunk.data)
        # print("\n\n")
        pass
# Out:
# Uploading:  26%|██▋       | 41/156 [2:08:27<6:00:18, 187.98s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 10
#       7 client = get_sync_client(url="http://localhost:2024")
#       9 for path in tqdm(pdf_paths, desc=f"Uploading"):
# ---> 10     for chunk in client.runs.stream(
#      11         None,
#      12         "index",
#      13         input={
#      14             "messages":[
#      15                 {"role": "human",
#      16                 "content": f"upload {path}"}
#      17             ]
#      18         },
#      19         stream_mode="updates"
#      20     ):
#      21         # print(f"Receiving new event of type: {chunk.event}")
#      22         # print(chunk.data)
#      23         # print("\n\n")
#      24         pass
#
# File ~/UIT_DOCS_AGENT/.venv/lib/python3.13/site-packages/langgraph_sdk/client.py:3876, in SyncHttpClient.stream(self, path, method, json, params, headers, on_response)
#    3874 decoder = SSEDecoder()
#    3875 try:
# -> 3876     for line in iter_lines_raw(res):
#    3877         sse = decoder.decode(line.rstrip(b"\n"))
#    3878         if sse is not None:
#
# File ~/UIT_DOCS_AGENT/.venv/lib/python3.13/site-packages/langgraph_sdk/sse.py:153, in iter_lines_raw(response)
#     151 def iter_lines_raw(response: httpx.Response) -> Iterator[BytesLike]:
#     152     decoder = BytesLineDecoder()
# --> 153     for chunk in response.iter_bytes():
#     154         for line in decoder.decode(chunk):
#     155             yield line
#
# File ~/UIT_DOCS_AGENT/.venv/lib/python3.13/site-packages/httpx/_models.py:897, in Response.iter_bytes(self, chunk_size)
#     895 chunker = ByteChunker(chunk_size=chunk_size)
#     896 with request_context(request=self._request):
# --> 897     for raw_bytes in self.iter_raw():
#     898         decoded = decoder.decode(raw_bytes)
#     899         for chunk in chunker.decode(decoded):
#
# File ~/UIT_DOCS_AGENT/.venv/lib/python3.13/site-packages/httpx/_models.py:951, in Response.iter_raw(self, chunk_size)
#     948 chunker = ByteChunker(chunk_size=chunk_size)
#     950 with request_context(request=self._request):
# --> 951     for raw_stream_bytes in self.stream:
#     952         self._num_bytes_downloaded += len(raw_stream_bytes)
#     953         for chunk in chunker.decode(raw_stream_bytes):
#
# File ~/UIT_DOCS_AGENT/.venv/lib/python3.13/site-packages/httpx/_client.py:153, in BoundSyncStream.__iter__(self)
#     152 def __iter__(self) -> typing.Iterator[bytes]:
# --> 153     for chunk in self._stream:
#     154         yield chunk
#
# File ~/UIT_DOCS_AGENT/.venv/lib/python3.13/site-packages/httpx/_transports/default.py:127, in ResponseStream.__iter__(self)
#     125 def __iter__(self) -> typing.Iterator[bytes]:
#     126     with map_httpcore_exceptions():
# --> 127         for part in self._httpcore_stream:
#     128             yield part
#
# File ~/UIT_DOCS_AGENT/.venv/lib/python3.13/site-packages/httpcore/_sync/connection_pool.py:407, in PoolByteStream.__iter__(self)
#     405 except BaseException as exc:
#     406     self.close()
# --> 407     raise exc from None
#
# File ~/UIT_DOCS_AGENT/.venv/lib/python3.13/site-packages/httpcore/_sync/connection_pool.py:403, in PoolByteStream.__iter__(self)
#     401 def __iter__(self) -> typing.Iterator[bytes]:
#     402     try:
# --> 403         for part in self._stream:
#     404             yield part
#     405     except BaseException as exc:
#
# File ~/UIT_DOCS_AGENT/.venv/lib/python3.13/site-packages/httpcore/_sync/http11.py:342, in HTTP11ConnectionByteStream.__iter__(self)
#     340 with ShieldCancellation():
#     341     self.close()
# --> 342 raise exc
#
# File ~/UIT_DOCS_AGENT/.venv/lib/python3.13/site-packages/httpcore/_sync/http11.py:334, in HTTP11ConnectionByteStream.__iter__(self)
#     332 try:
#     333     with Trace("receive_response_body", logger, self._request, kwargs):
# --> 334         for chunk in self._connection._receive_response_body(**kwargs):
#     335             yield chunk
#     336 except BaseException as exc:
#     337     # If we get an exception while streaming the response,
#     338     # we want to close the response (and possibly the connection)
#     339     # before raising that exception.
#
# File ~/UIT_DOCS_AGENT/.venv/lib/python3.13/site-packages/httpcore/_sync/http11.py:203, in HTTP11Connection._receive_response_body(self, request)
#     200 timeout = timeouts.get("read", None)
#     202 while True:
# --> 203     event = self._receive_event(timeout=timeout)
#     204     if isinstance(event, h11.Data):
#     205         yield bytes(event.data)
#
# File ~/UIT_DOCS_AGENT/.venv/lib/python3.13/site-packages/httpcore/_sync/http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)    227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~/UIT_DOCS_AGENT/.venv/lib/python3.13/site-packages/httpcore/_backends/sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# KeyboardInterrupt:

# %%
from PyPDF2 import PdfReader

def get_pdf_metadata(file_path):
    reader = PdfReader(file_path)
    metadata = reader.metadata  # returns a dictionary-like object
    
    print("=== PDF Metadata ===")
    if metadata:
        for key, value in metadata.items():
            print(f"{key}: {value}")
    else:
        print("No metadata found in this PDF.")

    # Check for possible source-like fields
    possible_source_fields = ["Source", "URL", "Download", "Origin", "Producer"]
    print("\n=== Possible Source Information ===")
    found = False
    for key, value in metadata.items():
        print(f"{key}: {value}")

# Example usage
# !pwd
get_pdf_metadata("data/daa/quy-dinh/quy-dinh-bo-gddt/pdf/01_2017_qd-ttg_ban_hanh_danh_muc_gddt_cua_he_thong_giao_duc_quoc_dan.pdf")
# Out:
# /Users/jajajou1778/UIT_DOCS_AGENT
# === PDF Metadata ===
# /Producer: PDFill: Free PDF Writer and Tools; modified using VGCA.Base 5.2.1 (c) 1T3XT BVBA
# /ModDate: D:20170124141816+07'00'
# /CreationDate: D:20170124140312+07'00'
#
# === Possible Source Information ===
# /Producer: PDFill: Free PDF Writer and Tools; modified using VGCA.Base 5.2.1 (c) 1T3XT BVBA
